# %% [markdown]
# # LO3: arXiv

# %% [markdown]
# This includes the tool definitions and execution, as well as the chatbot code.

# %% [markdown]
# ## Import Libraries

# %%
import arxiv
import json
import os
from typing import List
from dotenv import load_dotenv
import anthropic

# %% [markdown]
# ## Tool Functions

# %%
PAPER_DIR = "papers"

# %% [markdown]
# The first tool searches for relevant arXiv papers based on a topic and stores the papers' info in a JSON file (title, authors, summary, paper url and the publication date). The JSON files are organized by topics in the `papers` directory. The tool does not download the papers.

# %%
def search_papers(topic: str, max_results: int = 5) -> List[str]:
    """
    Search for papers on arXiv based on a topic and store their information.
    
    Args:
        topic: The topic to search for
        max_results: Maximum number of results to retrieve (default: 5)
        
    Returns:
        List of paper IDs found in the search
    """
    
    # Use arxiv to find the papers 
    client = arxiv.Client()

    # Search for the most relevant articles matching the queried topic
    search = arxiv.Search(
        query = topic,
        max_results = max_results,
        sort_by = arxiv.SortCriterion.Relevance
    )

    papers = client.results(search)
    
    # Create directory for this topic
    path = os.path.join(PAPER_DIR, topic.lower().replace(" ", "_"))
    os.makedirs(path, exist_ok=True)
    
    file_path = os.path.join(path, "papers_info.json")

    # Try to load existing papers info
    try:
        with open(file_path, "r") as json_file:
            papers_info = json.load(json_file)
    except (FileNotFoundError, json.JSONDecodeError):
        papers_info = {}

    # Process each paper and add to papers_info  
    paper_ids = []
    for paper in papers:
        paper_ids.append(paper.get_short_id())
        paper_info = {
            'title': paper.title,
            'authors': [author.name for author in paper.authors],
            'summary': paper.summary,
            'pdf_url': paper.pdf_url,
            'published': str(paper.published.date())
        }
        papers_info[paper.get_short_id()] = paper_info
    
    # Save updated papers_info to json file
    with open(file_path, "w") as json_file:
        json.dump(papers_info, json_file, indent=2)
    
    print(f"Results are saved in: {file_path}")
    
    return paper_ids

# %%
search_papers("computers", 7)
# Out:
# Results are saved in: papers/computers/papers_info.json
# ['1310.7911v2',
#  'math/9711204v1',
#  '2208.00733v1',
#  '2504.07020v1',
#  '2403.03925v1',
#  'quant-ph/0003151v1',
#  '1308.1806v1']

# %% [markdown]
# The second tool looks for information about a specific paper across all topic directories inside the `papers` directory.

# %%
def extract_info(paper_id: str) -> str:
    """
    Search for information about a specific paper across all topic directories.
    
    Args:
        paper_id: The ID of the paper to look for
        
    Returns:
        JSON string with paper information if found, error message if not found
    """
 
    for item in os.listdir(PAPER_DIR):
        item_path = os.path.join(PAPER_DIR, item)
        if os.path.isdir(item_path):
            file_path = os.path.join(item_path, "papers_info.json")
            if os.path.isfile(file_path):
                try:
                    with open(file_path, "r") as json_file:
                        papers_info = json.load(json_file)
                        if paper_id in papers_info:
                            return json.dumps(papers_info[paper_id], indent=2)
                except (FileNotFoundError, json.JSONDecodeError) as e:
                    print(f"Error reading {file_path}: {str(e)}")
                    continue
    
    return f"There's no saved information related to paper {paper_id}."

# %%
extract_info('1310.7911v2')
# Out:
# '{\n  "title": "Compact manifolds with computable boundaries",\n  "authors": [\n    "Zvonko Iljazovic"\n  ],\n  "summary": "We investigate conditions under which a co-computably enumerable closed set\\nin a computable metric space is computable and prove that in each locally\\ncomputable computable metric space each co-computably enumerable compact\\nmanifold with computable boundary is computable. In fact, we examine the notion\\nof a semi-computable compact set and we prove a more general result: in any\\ncomputable metric space each semi-computable compact manifold with computable\\nboundary is computable. In particular, each semi-computable compact\\n(boundaryless) manifold is computable.",\n  "pdf_url": "http://arxiv.org/pdf/1310.7911v2",\n  "published": "2013-10-29"\n}'

# %% [markdown]
# ## Tool Schema

# %% [markdown]
# Here are the schema of each tool which you will provide to the LLM.

# %%
tools = [
    {
        "name": "search_papers",
        "description": "Search for papers on arXiv based on a topic and store their information.",
        "input_schema": {
            "type": "object",
            "properties": {
                "topic": {
                    "type": "string",
                    "description": "The topic to search for"
                }, 
                "max_results": {
                    "type": "integer",
                    "description": "Maximum number of results to retrieve",
                    "default": 5
                }
            },
            "required": ["topic"]
        }
    },
    {
        "name": "extract_info",
        "description": "Search for information about a specific paper across all topic directories.",
        "input_schema": {
            "type": "object",
            "properties": {
                "paper_id": {
                    "type": "string",
                    "description": "The ID of the paper to look for"
                }
            },
            "required": ["paper_id"]
        }
    }
]

# %% [markdown]
# ## Tool Mapping

# %% [markdown]
# This code handles tool mapping and execution.

# %%
mapping_tool_function = {
    "search_papers": search_papers,
    "extract_info": extract_info
}

def execute_tool(tool_name, tool_args):
    
    result = mapping_tool_function[tool_name](**tool_args)

    if result is None:
        result = "The operation completed but didn't return any results."
        
    elif isinstance(result, list):
        result = ', '.join(result)
        
    elif isinstance(result, dict):
        # Convert dictionaries to formatted JSON strings
        result = json.dumps(result, indent=2)
    
    else:
        # For any other type, convert using str()
        result = str(result)
    return result

# %% [markdown]
# ## AI App:

# %% [markdown]
# The chatbot handles the user's queries one by one, but it does not persist memory across the queries.

# %%
load_dotenv() 
client = anthropic.Anthropic()

# %% [markdown]
# ### Query Processing

# %%
def process_query(query):
    
    messages = [{'role': 'user', 'content': query}]
    
    response = client.messages.create(max_tokens = 2024,
                                  model = 'claude-3-7-sonnet-20250219', 
                                  tools = tools,
                                  messages = messages)
    
    process_query = True
    while process_query:
        assistant_content = []

        for content in response.content:
            if content.type == 'text':
                
                print(content.text)
                assistant_content.append(content)
                
                if len(response.content) == 1:
                    process_query = False
            
            elif content.type == 'tool_use':
                
                assistant_content.append(content)
                messages.append({'role': 'assistant', 'content': assistant_content})
                
                tool_id = content.id
                tool_args = content.input
                tool_name = content.name
                print(f"Calling tool {tool_name} with args {tool_args}")
                
                result = execute_tool(tool_name, tool_args)
                messages.append({"role": "user", 
                                  "content": [
                                      {
                                          "type": "tool_result",
                                          "tool_use_id": tool_id,
                                          "content": result
                                      }
                                  ]
                                })
                response = client.messages.create(max_tokens = 2024,
                                  model = 'claude-3-7-sonnet-20250219', 
                                  tools = tools,
                                  messages = messages) 
                
                if len(response.content) == 1 and response.content[0].type == "text":
                    print(response.content[0].text)
                    process_query = False

# %% [markdown]
# ### Loop

# %%
def chat_loop():
    print("Type your queries or 'quit' to exit.")
    while True:
        try:
            query = input("\nQuery: ").strip()
            if query.lower() == 'quit':
                break
    
            process_query(query)
            print("\n")
        except Exception as e:
            print(f"\nError: {str(e)}")

# %% [markdown]
# Feel free to interact with the chatbot. Here's an example query:
#
# - Search for 2 papers on "LLM interpretability"
#
# To access the `papers` folder: 1) click on the `File` option on the top menu of the notebook and 2) click on `Open` and then 3) click on `L3`.

# %%
chat_loop()
# Out:
# Type your queries or 'quit' to exit.
# Query:  LLM Interpretability
# I'd be happy to help you search for papers on LLM interpretability. This is an important research area focused on understanding how large language models work internally.
#
# Let me search for recent papers on this topic for you.
# Calling tool search_papers with args {'topic': 'LLM interpretability', 'max_results': 5}
# Results are saved in: papers/llm_interpretability/papers_info.json
# I've found 5 papers related to LLM interpretability. Let me get more detailed information about each of them:
# Calling tool extract_info with args {'paper_id': '2412.07992v3'}
# Calling tool extract_info with args {'paper_id': '2402.01761v1'}
# Calling tool extract_info with args {'paper_id': '2407.04307v1'}
# Calling tool extract_info with args {'paper_id': '2408.13006v2'}
# Calling tool extract_info with args {'paper_id': '2308.08728v1'}
# # Summary of LLM Interpretability Papers
#
# Based on the search results, here are five recent papers on LLM interpretability:
#
# 1. **Concept Bottleneck Large Language Models** (Dec 2024)
#    - Authors: Chung-En Sun, Tuomas Oikarinen, Berk Ustun, Tsui-Wei Weng
#    - Introduces CB-LLMs that integrate intrinsic interpretability directly into LLMs
#    - Focuses on building inherently interpretable models rather than relying on post-hoc interpretations
#    - Shows competitive performance with traditional black-box models while providing explicit reasoning
#    - Enables concept detection, controlled generation, and safer outputs
#
# 2. **Rethinking Interpretability in the Era of Large Language Models** (Jan 2024)
#    - Authors: Chandan Singh, Jeevana Priya Inala, Michel Galley, Rich Caruana, Jianfeng Gao
#    - Position paper that reviews existing methods to evaluate LLM interpretation
#    - Discusses both interpreting LLMs and using LLMs for explanation
#    - Highlights how LLMs can redefine interpretability with a more ambitious scope
#    - Identifies research priorities: using LLMs to analyze new datasets and generate interactive explanations
#
# 3. **Crafting Large Language Models for Enhanced Interpretability** (July 2024)
#    - Authors: Chung-En Sun, Tuomas Oikarinen, Tsui-Wei Weng
#    - Introduces the Concept Bottleneck LLM (CB-LLM) with built-in interpretability
#    - Proposes an Automatic Concept Correction (ACC) strategy to narrow performance gaps
#    - Aims to combine high accuracy with clear interpretability
#
# 4. **Systematic Evaluation of LLM-as-a-Judge in LLM Alignment Tasks** (Aug 2024)
#    - Authors: Hui Wei, Shenghua He, Tian Xia, et al.
#    - Evaluates LLM-as-a-Judge approaches for alignment tasks
#    - Defines theoretically interpretable evaluation metrics
#    - Examines effects of prompt templates on LLM judge reliability
#    - Provides an open-source framework to evaluate reliability and alignment
#
# 5. **LLM-FuncMapper: Function Identification for Interpreting Complex Clauses** (Aug 2023)
#    - Authors: Zhe Zheng, Ke-Yin Chen, Xin-Yu Cao, et al.
#    - Focuses on using LLMs to interpret complex regulatory clauses in building codes
#    - Identifies predefined functions needed for interpretation using LLMs
#    - Shows promising results in automated rule interpretation
#    - One of the first attempts to use LLMs for understanding complex regulatory clauses
#
# These papers represent various approaches to LLM interpretability, from building inherently interpretable models to using LLMs as interpretation tools and developing frameworks to evaluate interpretability methods.
# Query:  research papers AI use in MRI
# I'll help you search for research papers on AI use in MRI. Let me search for relevant papers on this topic.
# Calling tool search_papers with args {'topic': 'AI use in MRI', 'max_results': 5}
# Results are saved in: papers/ai_use_in_mri/papers_info.json
# Great! I've found 5 papers related to AI use in MRI. Let me extract more detailed information about each of these papers so I can provide you with a comprehensive summary.
# Calling tool extract_info with args {'paper_id': '2502.02351v1'}
# Calling tool extract_info with args {'paper_id': '2502.00146v1'}
# Calling tool extract_info with args {'paper_id': '2310.07250v3'}
# Calling tool extract_info with args {'paper_id': '2404.19665v1'}
# Calling tool extract_info with args {'paper_id': '2310.04630v1'}
# Based on my search, here's a summary of recent research papers on AI use in MRI:
#
# # AI Applications in MRI: Research Overview
#
# ## 1. MRI Protocol Optimization
# **Paper:** "Exploring the Feasibility of AI-Assisted Spine MRI Protocol Optimization Using DICOM Image Metadata"
# - AI models achieved 77-93% F1 performance in classifying MRI image quality
# - Used DICOM metadata to identify optimal acquisition parameters
# - Helps medical physicists improve image quality and efficiency in clinical settings
#
# ## 2. Multimodal Cancer Detection
# **Paper:** "Multimodal MRI-Ultrasound AI for Prostate Cancer Detection Outperforms Radiologist MRI Interpretation"
# - Combined MRI and ultrasound images to enhance prostate cancer detection
# - Multimodal AI approach achieved 80% sensitivity and 42% Lesion Dice score
# - Outperformed both radiologists and unimodal approaches, improving targeting during biopsy
#
# ## 3. Synthesizing Missing MRI Sequences
# **Paper:** "Synthesizing Missing MRI Sequences from Available Modalities using Generative Adversarial Networks"
# - Used GANs to generate missing MRI sequences from available ones
# - Particularly useful for glioblastoma assessment when all four standard sequences aren't available
# - Enables more complete diagnostic capabilities for clinicians
#
# ## 4. Advanced AI Toolbox for MRI
# **Paper:** "ATOMMIC: An Advanced Toolbox for Multitask Medical Imaging Consistency"
# - Open-source toolbox streamlining AI applications across the MRI workflow
# - Supports multiple tasks including reconstruction, parameter mapping, and segmentation
# - Enables MultiTask Learning (MTL) for improved generalization
# - Physics-based models showed superior performance for highly accelerated acquisitions
#
# ## 5. Generative Models for Brain MRIs
# **Paper:** "Metadata-Conditioned Generative Models to Synthesize Anatomically-Plausible 3D Brain MRIs"
# - "BrainSynth" model creates metadata-conditioned MRIs (e.g., age and sex-specific)
# - Over half of brain regions in synthetic MRIs were anatomically accurate
# - Synthetic data improved training of CNNs to identify accelerated aging effects
#
# These papers demonstrate the diverse applications of AI in MRI, from improving acquisition protocols and image reconstruction to enhancing diagnostic capabilities and generating synthetic data for training. The research shows AI's potential to optimize clinical workflows, improve diagnostic accuracy, and advance neuroimaging research.
# Query:  AI documented clinical notes
# I'd be happy to search for papers about AI documented clinical notes for you. This is an interesting topic at the intersection of artificial intelligence, healthcare, and documentation. Let me search arXiv for relevant papers.
# Calling tool search_papers with args {'topic': 'AI documented clinical notes', 'max_results': 5}
# Results are saved in: papers/ai_documented_clinical_notes/papers_info.json
# Great! I've found 5 papers related to AI documented clinical notes. Let me gather more detailed information about each of these papers to provide you with a comprehensive overview.
# Calling tool extract_info with args {'paper_id': '2405.18346v1'}
# Calling tool extract_info with args {'paper_id': '2503.16504v1'}
# Calling tool extract_info with args {'paper_id': '2503.15526v1'}
# Calling tool extract_info with args {'paper_id': '2409.16307v1'}
# Calling tool extract_info with args {'paper_id': '2410.15528v1'}
# # AI Documented Clinical Notes: Research Overview
#
# Based on the papers I've found, here's a comprehensive overview of current research on AI documented clinical notes:
#
# ## Key Findings
#
# ### 1. AI Tools for Clinical Documentation
#
# Recent research focuses on using AI, particularly large language models (LLMs), to automate and enhance clinical note creation. The papers show various approaches:
#
# - **Intelligent Clinical Documentation** (Biswas & Talukdar, 2024): Explores using generative AI to create SOAP (Subjective, Objective, Assessment, Plan) and BIRP (Behavior, Intervention, Response, Plan) notes through natural language processing and automatic speech recognition to transcribe patient-clinician interactions.
#
# - **DeepScore** (Oleson, 2024): Presents DeepScribe's methodologies for assessing AI-generated clinical documentation quality, focusing on various metrics and a composite quality index.
#
# - **Sporo AI Scribe** (Lee et al., 2024): Compares Sporo's multi-agent AI scribe system with OpenAI's GPT-4o Mini, showing Sporo AI consistently outperformed GPT-4o Mini in clinical content recall, precision, and F1 scores.
#
# ### 2. Quality Assessment of AI-Generated Notes
#
# Several papers focus on evaluating the quality of AI-generated clinical documentation:
#
# - **The Human Notes Evaluator** (Sultan, 2025): An open-source tool using the Physician Documentation Quality Instrument (PDQI-9) framework to assess clinical note quality and differentiate between human and AI authorship.
#
# - **Pediatric Rehabilitation SOAP-Notes** (Amenyo et al., 2025): Evaluates two AI tools (Copilot and KAUWbot) for generating SOAP notes in pediatric rehabilitation settings, finding AI-generated notes comparable to human-authored notes.
#
# ### 3. Benefits of AI Documentation
#
# The research highlights several benefits of AI-assisted clinical documentation:
#
# - **Time savings** for healthcare professionals
# - **Reduced burnout** and administrative burden
# - **Improved documentation quality** and consistency
# - **Enhanced patient-centered care** by allowing clinicians to focus more on patients
#
# ### 4. Challenges and Considerations
#
# The papers also address important challenges:
#
# - **Ethical considerations** including patient confidentiality and model biases
# - **Accuracy concerns** as documentation errors can lead to clinical consequences
# - **Medical language complexity** requiring specialized AI models
# - **Need for human oversight** and editing of AI-generated content
#
# ## Conclusion
#
# The research suggests AI has significant potential to revolutionize clinical documentation by reducing administrative burdens while maintaining or improving quality. Most studies emphasize the importance of a collaborative approach where AI assists healthcare professionals rather than replacing them completely. The field continues to evolve with new evaluation frameworks and specialized models for different clinical contexts.
#
# Would you like me to elaborate on any specific aspect of AI documented clinical notes from these papers?

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output generated by AI chat models can vary with each execution due to their dynamic, probabilistic nature. Don't be surprised if your results differ from those shown in the video.</p>

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b> To Access the <code>requirements.txt</code> file or the <code>papers</code> folder: </b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em> and finally 3) click on <em>"L3"</em>.
# </div>

# %% [markdown]
# In the next lessons, you will take out the tool definitions to wrap them in an MCP server. Then you will create an MCP client inside the chatbot to make the chatbot MCP compatible.

# %% [markdown]
# ## Resources
#
# [Guide on how to implement tool use](https://docs.anthropic.com/en/docs/build-with-claude/tool-use/overview#how-to-implement-tool-use)

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
#
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# </div>

# %%
# !cat papers/requirements.txt
